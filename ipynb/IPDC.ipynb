# %%
import pandas as pd
from glob import glob

# %%
#get the dataset and clean .

#get the column names to be in proper format, 
#standardize the column names
#extract year and month column as separate from archive_date

#2020 data
dataset20 = pd.read_csv('IPDC Waiting List By Group Hospital 2020.csv')
dataset20.isnull().sum()
# Out:
# Archive_Date      0
# Hospital_Group    0
# Hospital_HIPE     0
# Hospital_Name     0
# Specialty_HIPE    0
# Specialty_Name    0
# Case_Type         0
# Adult_Child       0
# Age_Profile       0
# Time_Bands        0
# Total             0
# dtype: int64

# %%
#2019 data
dataset19 = pd.read_csv('IPDC Waiting List By Group Hospital 2019.csv')
dataset19.isnull().sum()
# Out:
# Archive_Date      0
# Hospital_Group    0
# Hospital_HIPE     0
# Hospital_Name     0
# Specialty_HIPE    0
# Specialty_Name    0
# Case_Type         0
# Adult_Child       0
# Age_Profile       0
# Time_Bands        0
# Total             0
# dtype: int64

# %%
#2018 data
dataset18 = pd.read_csv('IPDC Waiting List By Group Hospital 2018.csv')
dataset18.isnull().sum()
# Out:
# Archive_Date      0
# Hospital_Group    0
# Hospital_HIPE     0
# Hospital_Name     0
# Specialty_HIPE    0
# Specialty_Name    0
# Case_Type         0
# Adult_Child       0
# Age_Profile       0
# Time_Bands        0
# Total             0
# dtype: int64

# %%
#2017 data
dataset17 = pd.read_csv('IPDC Waiting List By Group Hospital 2017.csv')
dataset17.isnull().sum()


#Aligin the naming of dataset16 to other datasets so that merged data will be proper
dataset17.rename(columns={'Archive Date':'Archive_Date'}, 
                 inplace=True)

dataset17.rename(columns={'Group':'Hospital_Group'}, 
                 inplace=True)

dataset17.rename(columns={'Hospital HIPE':'Hospital_HIPE'}, 
                 inplace=True)

dataset17.rename(columns={'Hospital':'Hospital_Name'}, 
                 inplace=True)

dataset17.rename(columns={'Specialty HIPE':'Specialty_HIPE'}, 
                 inplace=True)

dataset17.rename(columns={'Speciality':'Specialty_Name'}, 
                 inplace=True)

dataset17.rename(columns={'Case Type':'Case_Type'}, 
                 inplace=True)

dataset17.rename(columns={'Adult/Child':'Adult_Child'}, 
                 inplace=True)

dataset17.rename(columns={'Age Profile':'Age_Profile'}, 
                 inplace=True)

dataset17.rename(columns={'Time Bands':'Time_Bands'}, 
                 inplace=True)

dataset17.rename(columns={'Total':'Total'}, 
                 inplace=True)

dataset17.isnull().sum()
# Out:
# Archive_Date      0
# Hospital_Group    0
# Hospital_HIPE     0
# Hospital_Name     0
# Specialty_HIPE    0
# Specialty_Name    0
# Case_Type         0
# Adult_Child       0
# Age_Profile       0
# Time_Bands        0
# Total             0
# dtype: int64

# %%
#2016 data
dataset16 = pd.read_csv('IPDC Waiting List By Group Hospital 2016.csv')
dataset16.isnull().sum()

#Aligin the naming of dataset16 to other datasets so that merged data will be proper
dataset16.rename(columns={'Archive Date':'Archive_Date'}, 
                 inplace=True)

dataset16.rename(columns={'Group':'Hospital_Group'}, 
                 inplace=True)

dataset16.rename(columns={'Hospital HIPE':'Hospital_HIPE'}, 
                 inplace=True)

dataset16.rename(columns={'Hospital':'Hospital_Name'}, 
                 inplace=True)

dataset16.rename(columns={'Specialty HIPE':'Specialty_HIPE'}, 
                 inplace=True)

dataset16.rename(columns={'Specialty':'Specialty_Name'}, 
                 inplace=True)

dataset16.rename(columns={'Case Type':'Case_Type'}, 
                 inplace=True)

dataset16.rename(columns={'Adult/Child':'Adult_Child'}, 
                 inplace=True)

dataset16.rename(columns={'Age Categorisation':'Age_Profile'}, 
                 inplace=True)

dataset16.rename(columns={'Time Bands':'Time_Bands'}, 
                 inplace=True)

dataset16.rename(columns={'Count':'Total'}, 
                 inplace=True)

dataset16.isnull().sum()
# Out:
# Archive_Date      0
# Hospital_Group    0
# Hospital_HIPE     0
# Hospital_Name     0
# Specialty_HIPE    0
# Specialty_Name    0
# Case_Type         0
# Adult_Child       0
# Age_Profile       0
# Time_Bands        0
# Total             0
# dtype: int64

# %%
#2015 data
dataset15 = pd.read_csv('IPDC Waiting List By Group Hospital 2015.csv')
dataset15.isnull().sum()

#Aligin the naming of dataset16 to other datasets so that merged data will be proper
dataset15.rename(columns={'Archive Date':'Archive_Date'}, 
                 inplace=True)

dataset15.rename(columns={'Group':'Hospital_Group'}, 
                 inplace=True)

dataset15.rename(columns={'Hospital HIPE':'Hospital_HIPE'}, 
                 inplace=True)

dataset15.rename(columns={'Hospital':'Hospital_Name'}, 
                 inplace=True)

dataset15.rename(columns={'Specialty HIPE':'Specialty_HIPE'}, 
                 inplace=True)

dataset15.rename(columns={'Specialty':'Specialty_Name'}, 
                 inplace=True)

dataset15.rename(columns={'Case Type':'Case_Type'}, 
                 inplace=True)

dataset15.rename(columns={'Adult/Child':'Adult_Child'}, 
                 inplace=True)

dataset15.rename(columns={'Age Categorisation':'Age_Profile'}, 
                 inplace=True)

dataset15.rename(columns={'Time Bands':'Time_Bands'}, 
                 inplace=True)

dataset15.rename(columns={'Count':'Total'}, 
                 inplace=True)

dataset15.isnull().sum()
# Out:
# Archive_Date      0
# Hospital_Group    0
# Hospital_HIPE     0
# Hospital_Name     0
# Specialty_HIPE    0
# Specialty_Name    0
# Case_Type         0
# Adult_Child       0
# Age_Profile       0
# Time_Bands        0
# Total             0
# dtype: int64

# %%
#2014 data
dataset14 = pd.read_csv('IPDC Waiting List By Group Hospital 2014.csv')
dataset14.isnull().sum()

#Aligin the naming of dataset16 to other datasets so that merged data will be proper
dataset14.rename(columns={'Archive Date':'Archive_Date'}, 
                 inplace=True)

dataset14.rename(columns={'Group':'Hospital_Group'}, 
                 inplace=True)

dataset14.rename(columns={'Hospital HIPE':'Hospital_HIPE'}, 
                 inplace=True)

dataset14.rename(columns={'Hospital':'Hospital_Name'}, 
                 inplace=True)

dataset14.rename(columns={'Specialty HIPE':'Specialty_HIPE'}, 
                 inplace=True)

dataset14.rename(columns={'Specialty':'Specialty_Name'}, 
                 inplace=True)

dataset14.rename(columns={'Case Type':'Case_Type'}, 
                 inplace=True)

dataset14.rename(columns={'Adult/Child':'Adult_Child'}, 
                 inplace=True)

dataset14.rename(columns={'Age Categorisation':'Age_Profile'}, 
                 inplace=True)

dataset14.rename(columns={'Time Bands':'Time_Bands'}, 
                 inplace=True)

dataset14.rename(columns={'Count':'Total'}, 
                 inplace=True)

dataset14.isnull().sum()
# Out:
# Archive_Date      0
# Hospital_Group    0
# Hospital_HIPE     0
# Hospital_Name     0
# Specialty_HIPE    0
# Specialty_Name    0
# Case_Type         0
# Adult_Child       0
# Age_Profile       0
# Time_Bands        0
# Total             0
# dtype: int64

# %%
#get the dataset and clean .

#get the column names to be in proper format, 
#standardize the column names
#extract year and month column as separate from archive_date

# 2020 data
######dataset20 = pd.read_csv('OP Waiting List By Group Hospital 2019.csv')
dataset20.columns = dataset20.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
dataset20['year'] = pd.DatetimeIndex(dataset20['Archive_Date']).year
dataset20['month'] = pd.DatetimeIndex(dataset20['Archive_Date']).month
print(dataset20.head)

#2019 data
#dataset19 = pd.read_csv('OP Waiting List By Group Hospital 2019.csv')
dataset19.columns = dataset19.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
dataset19['year'] = pd.DatetimeIndex(dataset19['Archive_Date']).year
dataset19['month'] = pd.DatetimeIndex(dataset19['Archive_Date']).month
print(dataset19.head)

#2018 data
# dataset18 = pd.read_csv('OP Waiting List By Group Hospital 2018.csv')
dataset18.columns = dataset18.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print(dataset18.head)
dataset18['year'] = pd.DatetimeIndex(dataset18['Archive_Date']).year
dataset18['month'] = pd.DatetimeIndex(dataset18['Archive_Date']).month

#2017 data
# dataset17 = pd.read_csv('OP Waiting List By Group Hospital 2017.csv')
dataset17.columns = dataset17.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print(dataset17.head)
dataset17['year'] = pd.DatetimeIndex(dataset17['Archive_Date']).year
dataset17['month'] = pd.DatetimeIndex(dataset17['Archive_Date']).month
print(dataset17.head)

#2016 data
#dataset16 = pd.read_csv('OP Waiting List By Group Hospital 2016.csv')
dataset16.columns = dataset16.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print(dataset16.head)
dataset16['year'] = pd.DatetimeIndex(dataset16['Archive_Date']).year
dataset16['month'] = pd.DatetimeIndex(dataset16['Archive_Date']).month
print(dataset16.head)

#2015 data
#dataset15 = pd.read_csv('OP Waiting List By Group Hospital 2016.csv')
dataset15.columns = dataset15.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print(dataset15.head)
dataset15['year'] = pd.DatetimeIndex(dataset15['Archive_Date']).year
dataset15['month'] = pd.DatetimeIndex(dataset15['Archive_Date']).month
print(dataset15.head)

#2014 data
#dataset14 = pd.read_csv('OP Waiting List By Group Hospital 2014.csv')
dataset14.columns = dataset14.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
print(dataset14.head)
dataset14['year'] = pd.DatetimeIndex(dataset14['Archive_Date']).year
dataset14['month'] = pd.DatetimeIndex(dataset14['Archive_Date']).month
print(dataset14.head)
# Out:
# <bound method NDFrame.head of      Archive_Date                         Hospital_Group  Hospital_HIPE  \
# 0      30/01/2020              Children's Health Ireland              0
# 1      30/01/2020              Children's Health Ireland              0
# 2      30/01/2020              Children's Health Ireland              0
# 3      30/01/2020              Children's Health Ireland              0
# 4      30/01/2020              Children's Health Ireland              0
# ...           ...                                    ...            ...
# 4247   30/01/2020  University of Limerick Hospital Group            918
# 4248   30/01/2020  University of Limerick Hospital Group            918
# 4249   30/01/2020  University of Limerick Hospital Group            918
# 4250   30/01/2020  University of Limerick Hospital Group            918
# 4251   30/01/2020  University of Limerick Hospital Group            918
#
# ...

# %%
#combine all dataset to one final
IPDC = dataset20.append(dataset19).append(dataset18).append(dataset17).append(dataset16).append(dataset15).append(dataset14)
IPDC.tail()
# Out:
#       Archive_Date                         Hospital_Group  Hospital_HIPE  \
# 35044   2014-12-23  University of Limerick Hospital Group            918
# 35045   2014-12-23  University of Limerick Hospital Group            918
# 35046   2014-12-23  University of Limerick Hospital Group            918
# 35047   2014-12-23  University of Limerick Hospital Group            918
# 35048   2014-12-23  University of Limerick Hospital Group            918
#
#                       Hospital_Name  Specialty_HIPE Specialty_Name Case_Type  \
# 35044  St. John's Hospital Limerick            8000   Anaesthetics  Day Case
# 35045  St. John's Hospital Limerick            8000   Anaesthetics  Day Case
# 35046  St. John's Hospital Limerick            8000   Anaesthetics  Day Case
# 35047  St. John's Hospital Limerick            8000   Anaesthetics  Day Case
# 35048  St. John's Hospital Limerick            8000   Anaesthetics  Day Case
#
#       Adult_Child Age_Profile    Time_Bands  Total  year  month
# ...

# %%
IPDC.count()
# Out:
# Archive_Date      294975
# Hospital_Group    294975
# Hospital_HIPE     294975
# Hospital_Name     294975
# Specialty_HIPE    294975
# Specialty_Name    294975
# Case_Type         294975
# Adult_Child       294975
# Age_Profile       294975
# Time_Bands        294975
# Total             294975
# year              294975
# month             294975
# dtype: int64

# %%
IPDC.isnull().sum()
# Out:
# Archive_Date      0
# Hospital_Group    0
# Hospital_HIPE     0
# Hospital_Name     0
# Specialty_HIPE    0
# Specialty_Name    0
# Case_Type         0
# Adult_Child       0
# Age_Profile       0
# Time_Bands        0
# Total             0
# year              0
# month             0
# dtype: int64

# %%
#extract the final dataset to excel 
IPDC.to_excel (r'IPDC_final.xlsx', index = None, header=True)

# %%
import pandas

excel_data_df = pandas.read_excel('IPDC_final.xlsx', sheet_name='Sheet1')

# print whole sheet data
print(excel_data_df)
# Out:
#        Archive_Date                         Hospital_Group  Hospital_HIPE  \
# 0        30/01/2020              Children's Health Ireland              0
# 1        30/01/2020              Children's Health Ireland              0
# 2        30/01/2020              Children's Health Ireland              0
# 3        30/01/2020              Children's Health Ireland              0
# 4        30/01/2020              Children's Health Ireland              0
# ...             ...                                    ...            ...
# 294970   2014-12-23  University of Limerick Hospital Group            918
# 294971   2014-12-23  University of Limerick Hospital Group            918
# 294972   2014-12-23  University of Limerick Hospital Group            918
# 294973   2014-12-23  University of Limerick Hospital Group            918
# 294974   2014-12-23  University of Limerick Hospital Group            918
#
#                        Hospital_Name  Specialty_HIPE  \
# ...

# %%
excel_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294975 entries, 0 to 294974
# Data columns (total 13 columns):
# Archive_Date      294975 non-null object
# Hospital_Group    294975 non-null object
# Hospital_HIPE     294975 non-null int64
# Hospital_Name     294975 non-null object
# Specialty_HIPE    294975 non-null int64
# Specialty_Name    294975 non-null object
# Case_Type         294975 non-null object
# Adult_Child       294975 non-null object
# Age_Profile       294975 non-null object
# Time_Bands        294975 non-null object
# Total             294975 non-null int64
# year              294975 non-null int64
# month             294975 non-null int64
# dtypes: int64(5), object(8)
# memory usage: 29.3+ MB

# %%
# Displays numbers of rows and columns
print(excel_data_df.shape)

print(excel_data_df.describe())
# Out:
# (294975, 13)
#        Hospital_HIPE  Specialty_HIPE          Total           year  \
# count  294975.000000   294975.000000  294975.000000  294975.000000
# mean      741.773727     2812.512406      17.580164    2016.763888
# std       282.478612     2439.189561      34.381580       1.674945
# min         0.000000        0.000000       1.000000    2014.000000
# 25%       600.000000     1503.000000       2.000000    2015.000000
# 50%       904.000000     2000.000000       5.000000    2017.000000
# 75%       915.000000     2603.000000      17.000000    2018.000000
# max      1270.000000     8800.000000     663.000000    2020.000000
#
#                month
# count  294975.000000
# mean        6.476898
# std         3.473257
# min         1.000000
# 25%         3.000000
# 50%         7.000000
# 75%         9.000000
# max        12.000000

# %%
excel_data_df['Time_Bands'] = excel_data_df['Time_Bands'].str.strip()

# %%
print(excel_data_df.head(20))
print(excel_data_df.tail(20))
# Out:
#    Archive_Date             Hospital_Group  Hospital_HIPE  \
# 0    30/01/2020  Children's Health Ireland              0
# 1    30/01/2020  Children's Health Ireland              0
# 2    30/01/2020  Children's Health Ireland              0
# 3    30/01/2020  Children's Health Ireland              0
# 4    30/01/2020  Children's Health Ireland              0
# 5    30/01/2020  Children's Health Ireland              0
# 6    30/01/2020  Children's Health Ireland              0
# 7    30/01/2020  Children's Health Ireland              0
# 8    30/01/2020  Children's Health Ireland              0
# 9    30/01/2020  Children's Health Ireland              0
# 10   30/01/2020  Children's Health Ireland              0
# 11   30/01/2020  Children's Health Ireland              0
# 12   30/01/2020  Children's Health Ireland              0
# 13   30/01/2020  Children's Health Ireland              0
# 14   30/01/2020  Children's Health Ireland              0
# ...

# %%
#extract the final dataset to excel 
excel_data_df.to_excel (r'IPDC_final_trimmed.xlsx', index = None, header=True)
